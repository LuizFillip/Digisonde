# %% [markdown]
# # IONOSONDE DATA ANALYSIS

# %%
from plotVerticaldrift import *

main()

# %%
from plotAllparameters import *

plotAllparameters(site = "Fortaleza")
# Out:
# C:\Users\Luiz\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Luiz\anaconda3\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\Luiz\anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
# C:\Users\Luiz\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   return func(*args, **kwargs)

# %%
6 // 2
# Out:
# 3
